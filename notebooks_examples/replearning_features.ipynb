# %% [markdown]
# # Features based on Representation learning strategies using Autoencoders
#
# Compute Features based on Representation learning strategies using convolutional and recurrent Autoencoders
#
# Two types of features are computed
#
# 1. 256 features extracted from the bottleneck layer of the autoencoders
# 2. 128 features based on the MSE between the decoded and input spectrograms of the autoencoder in different frequency regions
#
#
# Additionally, static (for all utterance) or dynamic (for each 500 ms speech segments) features can be computed:
#
# - The static feature vector is formed with 1536 features and contains (384 descriptors) x (4 functionals: mean, std, skewness, kurtosis)
#
# - The dynamic feature matrix is formed with the 384 descriptors computed for speech segments with 500ms length and 250ms time-shift

# %%
import sys
sys.path.append("../")
from replearning.replearning import RepLearning

# %%
replearningf=RepLearning('CAE')
file_audio="../audios/001_ddk1_PCGITA.wav"

# %% [markdown]
# ## Extract features and return them as a numpy array

# %%
features1=replearningf.extract_features_file(file_audio, static=True, plots=True, fmt="npy")
print(features1.shape)
# Out:
# /home/camilo/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1639: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# (1536,)

# %% [markdown]
# ## Extract static features and return them as a dataframe

# %%
features1=replearningf.extract_features_file(file_audio, static=True, plots=False, fmt="csv")
print(features1)
# Out:
#    mean_bottleneck_0  mean_bottleneck_1  mean_bottleneck_2  mean_bottleneck_3  \
# 0           -0.51014           0.807109           0.621138          -0.001076
#
#    mean_bottleneck_4  mean_bottleneck_5  mean_bottleneck_6  mean_bottleneck_7  \
# 0          -0.081697          -2.203802          -0.570493          -2.204587
#
#    mean_bottleneck_8  mean_bottleneck_9  ...  kurtosis_error_118  \
# 0           0.682683          -1.524909  ...           -0.883424
#
#    kurtosis_error_119  kurtosis_error_120  kurtosis_error_121  \
# 0           -1.047997           -1.201861           -1.401196
#
#    kurtosis_error_122  kurtosis_error_123  kurtosis_error_124  \
# 0           -1.565329           -1.406058           -1.411058
#
#    kurtosis_error_125  kurtosis_error_126  kurtosis_error_127
# 0           -1.312885           -1.089096           -1.296417
#
# [1 rows x 1536 columns]

# %% [markdown]
# ## Extract dynamic features and return them as a dataframe

# %%
features1=replearningf.extract_features_file(file_audio, static=False, plots=False, fmt="csv")
print(features1)
print(features1.head())
# Out:
# /home/camilo/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1639: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
#     bottleneck_0  bottleneck_1  bottleneck_2  bottleneck_3  bottleneck_4  \
# 0      -0.994415      0.283122      0.835239     -0.178610      0.100906
# 1      -0.498155      0.771888      0.427916      0.138079     -0.019998
# 2       0.199696      1.429044      0.469014      0.295332     -0.054008
# 3      -0.484749      1.050791      0.872225      0.053397     -0.098904
# 4      -0.057842      0.404780      0.646808     -0.608594     -0.051913
# 5      -0.425806      0.545309      1.225211     -0.914126     -0.209555
# 6      -0.222604      0.593376      0.477669      0.251547     -0.458011
# 7      -0.820728      1.467634      0.185545     -0.329484      0.508964
# 8      -0.786492      1.374277      0.153589      0.594447      0.578023
# ...

# %% [markdown]
# ## Extract dynamic features and return them as a torch tensor

# %%
features1=replearningf.extract_features_file(file_audio, static=False, plots=False, fmt="torch")
print(features1.dtype)
print(features1.size())
# Out:
# /home/camilo/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1639: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# torch.float32
# torch.Size([13, 384])

# %% [markdown]
# ## Extract static features from a path return them as a numpy array

# %%
path_audio="../audios/"
features1=replearningf.extract_features_path(path_audio, static=True, plots=False, fmt="npy")
print(features1.shape)
# Out:
# Processing 098_u1_PCGITA.wav: 100%|██████████| 4/4 [00:03<00:00,  1.16it/s]
# (4, 1536)
